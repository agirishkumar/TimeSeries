# %% [markdown]
# # univariate

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
data = pd.read_csv('.\TimeSeries\daily-min-temperatures.csv',
                  index_col = 0, parse_dates = True)
data.head()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
data.plot()
plt.ylabel('Min temp')
plt.title('Min temp in Southern Hemisphere From 1981 to 1990')
plt.show()
