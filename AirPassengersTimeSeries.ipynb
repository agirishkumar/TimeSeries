# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.8.0-cp39-cp39-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.1.1-cp39-cp39-win_amd64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.43.1-cp39-cp39-win_amd64.whl.metadata (155 kB)
#      ---------------------------------------- 0.0/155.5 kB ? eta -:--:--
#      --------------- ----------------------- 61.4/155.5 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 155.5/155.5 kB 3.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp39-cp39-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\adari\anaconda3\envs\timeseries\lib\site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\adari\anaconda3\envs\timeseries\lib\site-packages (from matplotlib) (23.1)
# Collecting pillow>=6.2.0 (from matplotlib)
#   Downloading Pillow-10.1.0-cp39-cp39-win_amd64.whl.metadata (9.6 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\adari\anaconda3\envs\timeseries\lib\site-packages (from matplotlib) (2.8.2)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Downloading importlib_resources-6.1.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting zipp>=3.1.0 (from importlib-resources>=3.2.0->matplotlib)
#   Downloading zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: six>=1.5 in c:\users\adari\anaconda3\envs\timeseries\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.0-cp39-cp39-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.7/7.6 MB 22.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.9/7.6 MB 24.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.1/7.6 MB 24.6 MB/s eta 0:00:01
#    --------------------- ------------------ 4.1/7.6 MB 23.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.4/7.6 MB 24.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.6/7.6 MB 24.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.6 MB 23.8 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 22.2 MB/s eta 0:00:00
# Downloading contourpy-1.1.1-cp39-cp39-win_amd64.whl (435 kB)
#    ---------------------------------------- 0.0/436.0 kB ? eta -:--:--
#    --------------------------------------- 436.0/436.0 kB 13.7 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.43.1-cp39-cp39-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------------- ------------------- 1.1/2.1 MB 35.3 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 27.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 27.3 MB/s eta 0:00:00
# Downloading importlib_resources-6.1.0-py3-none-any.whl (33 kB)
# Downloading kiwisolver-1.4.5-cp39-cp39-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.2 kB ? eta -:--:--
#    ---------------------------------------- 56.2/56.2 kB 2.9 MB/s eta 0:00:00
# Downloading Pillow-10.1.0-cp39-cp39-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------------- ------------------------- 1.0/2.6 MB 30.7 MB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.6 MB 26.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 23.8 MB/s eta 0:00:00
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.1 kB ? eta -:--:--
#    ---------------------------------------- 103.1/103.1 kB 6.2 MB/s eta 0:00:00
# Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Installing collected packages: zipp, pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, importlib-resources, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.43.1 importlib-resources-6.1.0 kiwisolver-1.4.5 matplotlib-3.8.0 pillow-10.1.0 pyparsing-3.1.1 zipp-3.17.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The following are some of the important input arguments for read_csv:
# •
# parse_dates mentions the datetime column in the dataset that needs to be parsed.
# •
# index_col mentions the column that is a unique identifier for the pandas dataframe. In most time series use cases, it’s the datetime column.
# •
# date_parser is a function to parse the dates (i.e., converts an input string to datetime format/type). pandas reads the data in YYYY-MM-DD HH:MM:SS format. Convert to this format when using the parser function.

# %%
date_parser_fn = lambda dates: pd.datetime.strptime(dates, '%Y-%m')

# %%
data = pd.read_csv('./Airpassengers.csv', parse_dates = ['Month'], index_col= 'Month', date_parser=date_parser_fn)
plt.plot(data)
plt.show()
# Out:
# C:\Users\adari\AppData\Local\Temp\ipykernel_18172\1686206692.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   date_parser_fn = lambda dates: pd.datetime.strptime(dates, '%Y-%m')
