# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.6 kB ? eta -:--:--
#    -------------------------------------- - 286.7/294.6 kB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 294.6/294.6 kB 3.6 MB/s eta 0:00:00
# ...

# %%
data = pd.read_csv('./TimeSeries/DailyDelhiClimateTrain.csv', parse_dates=['date'], index_col = 'date')

# %%
data.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
axs = data.plot(subplots=True, figsize=(15, 10), grid=True)
for ax in axs:
    ax.legend(loc='upper left')
plt.show()
