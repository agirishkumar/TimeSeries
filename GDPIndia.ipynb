# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
data = pd.read_csv('./TimeSeries/GDPIndia.csv' )

# %%
data.head()
# Out:
#    Year  GDPpercapita
# 0  1960     81.284764
# 1  1961     84.426437
# 2  1962     88.914919
# 3  1963    100.048592
# 4  1964    114.315161

# %%
data = data.set_index('Year')

# %%
plt.plot(data)

# %%
## Storing and retrieving as pickle

with open('./TimeSeries/gdp_india.pkl', 'wb') as file:
    pickle.dump(data, file)

# %%
with open('./TimeSeries/gdp_india.pkl', 'rb') as file:
    loaded_data = pickle.load(file)

# %%
loaded_data.plot()
# Out:
# <Axes: xlabel='Year'>
